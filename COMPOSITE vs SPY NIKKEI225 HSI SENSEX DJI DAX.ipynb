# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from __future__ import print_function
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '15ybzfQqm1tCxP0NiEqxIMk7qrAwfJVWpQYDMvYO2RK0'
SPY = 'SPY!B1:E1210'

# %%
import pickle
def gsheet_api_check(SCOPES):
    creds = None
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return creds

def pull_sheet_data(SCOPES,SAMPLE_SPREADSHEET_ID,SPY):
    creds = gsheet_api_check(SCOPES)
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range=SPY).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range=SPY).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
    
dataSPY = pull_sheet_data(SCOPES,SAMPLE_SPREADSHEET_ID,SPY)
dfSPY = pd.DataFrame(dataSPY[1:], columns=dataSPY[0])
dfSPY.head()
# Out:
# COMPLETE: Data copied
#                  Date   Close                Date    Open
# 0  5/18/2016 16:00:00  204.91  5/18/2016 16:00:00  204.44
# 1  5/19/2016 16:00:00   204.2  5/19/2016 16:00:00  204.06
# 2  5/20/2016 16:00:00  205.49  5/20/2016 16:00:00  204.92
# 3  5/23/2016 16:00:00  205.21  5/23/2016 16:00:00  205.51
# 4  5/24/2016 16:00:00  207.87  5/24/2016 16:00:00  206.17

# %%
DJI = 'DJI!B1:E1210'
def get_DJI(SCOPES,SAMPLE_SPREADSHEET_ID,DJI):
    creds = gsheet_api_check(SCOPES)
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range=DJI).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range=DJI).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
    
dataDJI = get_DJI(SCOPES,SAMPLE_SPREADSHEET_ID,DJI)
dfDJI = pd.DataFrame(dataDJI[1:], columns=dataDJI[0])
dfDJI.head()
# Out:
# COMPLETE: Data copied
#                  Date     Close                Date      Open
# 0  5/18/2016 16:00:00  17526.62  5/18/2016 16:00:00  17501.28
# 1  5/19/2016 16:00:00   17435.4  5/19/2016 16:00:00  17514.16
# 2  5/20/2016 16:00:00  17500.94  5/20/2016 16:00:00  17437.32
# 3  5/23/2016 16:00:00  17492.93  5/23/2016 16:00:00  17507.04
# 4  5/24/2016 16:00:00  17706.05  5/24/2016 16:00:00  17525.19

# %%
NIKKEI225 = 'NIKKEI225!B1:E1210'
def get_NIKKEI225(SCOPES,SAMPLE_SPREADSHEET_ID,NIKKEI225):
    creds = gsheet_api_check(SCOPES)
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range=NIKKEI225).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range=NIKKEI225).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
    
dataNIKKEI225 = get_NIKKEI225(SCOPES,SAMPLE_SPREADSHEET_ID,NIKKEI225)
dfNIKKEI225 = pd.DataFrame(dataNIKKEI225[1:], columns=dataNIKKEI225[0])
dfNIKKEI225.head()
# Out:
# COMPLETE: Data copied
#                  Date     Close                Date      Open
# 0  5/19/2016 15:00:00  16646.66  5/19/2016 15:00:00  16807.46
# 1  5/20/2016 15:00:00  16736.35  5/20/2016 15:00:00  16594.99
# 2  5/23/2016 15:00:00   16654.6  5/23/2016 15:00:00  16671.28
# 3  5/24/2016 15:00:00  16498.76  5/24/2016 15:00:00  16605.04
# 4  5/25/2016 15:00:00  16757.35  5/25/2016 15:00:00  16764.35

# %%
HSI = 'HSI!B1:E1210'
def get_HSI(SCOPES,SAMPLE_SPREADSHEET_ID,HSI):
    creds = gsheet_api_check(SCOPES)
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range=HSI).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range=HSI).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
    
dataHSI = get_HSI(SCOPES,SAMPLE_SPREADSHEET_ID,HSI)
dfHSI = pd.DataFrame(dataHSI[1:], columns=dataHSI[0])
dfHSI.head()
# Out:
# COMPLETE: Data copied
#                  Date     Close                Date      Open
# 0  5/19/2016 16:00:00  19694.33  5/19/2016 16:00:00  19729.63
# 1  5/20/2016 16:00:00   19852.2  5/20/2016 16:00:00  19631.71
# 2  5/23/2016 16:00:00  19809.03  5/23/2016 16:00:00  19788.13
# 3  5/24/2016 16:00:00  19830.43  5/24/2016 16:00:00  19828.02
# 4  5/25/2016 16:00:00  20368.05  5/25/2016 16:00:00  20156.76

# %%
COMPOSITE = 'COMPOSITE!B1:E1210'
def get_composite(SCOPES,SAMPLE_SPREADSHEET_ID,COMPOSITE):
    creds = gsheet_api_check(SCOPES)
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range=COMPOSITE).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range=COMPOSITE).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
    
datacomposite = get_composite(SCOPES,SAMPLE_SPREADSHEET_ID,COMPOSITE)
dfcomposite = pd.DataFrame(datacomposite[1:], columns=datacomposite[0])
dfcomposite.head()
# Out:
# COMPLETE: Data copied
#                  Date    Close                Date     Open
# 0  5/19/2016 15:00:00  4704.22  5/19/2016 15:00:00  4733.47
# 1  5/20/2016 15:00:00  4711.88  5/20/2016 15:00:00  4698.97
# 2  5/23/2016 15:00:00  4743.66  5/23/2016 15:00:00  4714.68
# 3  5/24/2016 15:00:00  4710.79  5/24/2016 15:00:00  4738.16
# 4  5/25/2016 15:00:00  4772.98  5/25/2016 15:00:00  4733.89

# %%
DAX = 'DAX!B1:E1210'
def get_DAX(SCOPES,SAMPLE_SPREADSHEET_ID,DAX):
    creds = gsheet_api_check(SCOPES)
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range=DAX).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range=DAX).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
    
dataDAX = get_composite(SCOPES,SAMPLE_SPREADSHEET_ID,DAX)
dfDAX = pd.DataFrame(dataDAX[1:], columns=dataDAX[0])
dfDAX.head()
# Out:
# COMPLETE: Data copied
#                  Date     Close                Date     Open
# 0  5/18/2016 20:00:00   9943.23  5/18/2016 20:00:00  9828.05
# 1  5/19/2016 20:00:00   9795.89  5/19/2016 20:00:00  9847.64
# 2  5/20/2016 20:00:00   9916.02  5/20/2016 20:00:00  9878.49
# 3  5/23/2016 20:00:00   9842.29  5/23/2016 20:00:00  9891.38
# 4  5/24/2016 20:00:00  10057.31  5/24/2016 20:00:00  9798.94

# %%
SENSEX = 'SENSEX!B1:E1210'
def get_SENSEX(SCOPES,SAMPLE_SPREADSHEET_ID,SENSEX):
    creds = gsheet_api_check(SCOPES)
    service = build('sheets', 'v4', credentials=creds)
    sheet = service.spreadsheets()
    result = sheet.values().get(
        spreadsheetId=SAMPLE_SPREADSHEET_ID,
        range=SENSEX).execute()
    values = result.get('values', [])
    
    if not values:
        print('No data found.')
    else:
        rows = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                  range=SENSEX).execute()
        data = rows.get('values')
        print("COMPLETE: Data copied")
        return data
    
dataSENSEX = get_composite(SCOPES,SAMPLE_SPREADSHEET_ID,SENSEX)
dfSENSEX = pd.DataFrame(dataSENSEX[1:], columns=dataSENSEX[0])
dfSENSEX.head()
# Out:
# COMPLETE: Data copied
#                  Date     Close                Date      Open
# 0  5/19/2016 15:30:00  25399.72  5/19/2016 15:30:00  25713.84
# 1  5/20/2016 15:30:00   25301.9  5/20/2016 15:30:00  25428.42
# 2  5/23/2016 15:30:00  25230.36  5/23/2016 15:30:00  25447.72
# 3  5/24/2016 15:30:00  25305.47  5/24/2016 15:30:00  25256.97
# 4  5/25/2016 15:30:00  25881.17  5/25/2016 15:30:00   25432.1

# %% [markdown]
# # Data Munging

# %%
#indicepanel=pd.DataFrame(index=dfcomposite.index)
indicepanel=pd.DataFrame(index=dfcomposite.index)
indicepanel = indicepanel.astype(float)

# %%
indicepanel = indicepanel.astype(float)

# %%
#indicepanel['HSI']=dfHSI['Open'].shift(-1).astype(float)-dfHSI['Open'].astype(float)

# %%
indicepanel['HSI']=dfHSI['Open'].astype(float)-dfHSI['Open'].shift(1).astype(float)
indicepanel['NIKKEI225']=dfNIKKEI225['Open'].astype(float)-dfNIKKEI225['Open'].shift(1).astype(float)
indicepanel['SPY']=dfSPY['Open'].astype(float)-dfSPY['Open'].shift(1).astype(float)
indicepanel['DAX']=dfDAX['Open'].astype(float)-dfDAX['Open'].shift(1).astype(float)
indicepanel['COMPOSITE']=dfcomposite['Open'].shift(-1).astype(float)-dfcomposite['Open'].astype(float)
indicepanel['DJI']=dfDJI['Open'].astype(float)-dfDJI['Open'].shift(1).astype(float)
indicepanel['SENSEX']=dfSENSEX['Open'].astype(float)-dfSENSEX['Open'].shift(1).astype(float)

# %%
indicepanel.head()
# Out:
#       HSI  NIKKEI225   SPY    DAX  COMPOSITE    DJI  SENSEX
# 0     NaN        NaN   NaN    NaN     -34.50    NaN     NaN
# 1  -97.92    -212.47 -0.38  19.59      15.71  12.88 -285.42
# 2  156.42      76.29  0.86  30.85      23.48 -76.84   19.30
# 3   39.89     -66.24  0.59  12.89      -4.27  69.72 -190.75
# 4  328.74     159.31  0.66 -92.44      43.68  18.15  175.13

# %%
indicepanel.isnull().sum()
# Out:
# HSI          1
# NIKKEI225    1
# SPY          1
# DAX          1
# COMPOSITE    1
# DJI          1
# SENSEX       1
# dtype: int64

# %%
# We can use method 'fillna()' from dataframe to forward filling the Nan values
# Then we can drop the reminding Nan values
indicepanel = indicepanel.fillna(method='ffill')
indicepanel = indicepanel.dropna()

# %%
# Lets check whether do we have Nan values in indicepanel now
indicepanel.isnull().sum()
# Out:
# HSI          0
# NIKKEI225    0
# SPY          0
# DAX          0
# COMPOSITE    0
# DJI          0
# SENSEX       0
# dtype: int64

# %%
print(indicepanel.shape)
# Out:
# (1205, 7)

# %%
indicepanel = indicepanel.astype(float)

# %%
# save this indicepanel for part 4.5
path_save = 'indicepanel.csv'
indicepanel.to_csv(path_save)

# %% [markdown]
# # Explore train data set

# %%
#split the data into (1)train set and (2)test set

Train = indicepanel.iloc[-1000:-500, :]
Test = indicepanel.iloc[-500:, :]
print(Train.shape, Test.shape)
# Out:
# (500, 7) (500, 7)

# %%
# Generate scatter matrix among all stock markets (and the price of SPY) to observe the association

from pandas.tools.plotting import scatter_matrix
sm = scatter_matrix(Train, figsize=(10, 10))

# %%
# Find the indice with largest correlation
corr_array = Train.iloc[:].corr()['COMPOSITE']
print(corr_array)
# Out:
# HSI         -0.049712
# NIKKEI225    0.050649
# SPY          0.012978
# DAX         -0.045479
# COMPOSITE    1.000000
# DJI         -0.039035
# SENSEX       0.010555
# Name: COMPOSITE, dtype: float64

# %%
formula = 'COMPOSITE~SPY+NIKKEI225+HSI+SENSEX+DJI+DAX'
lm = smf.ols(formula=formula, data=Train).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              COMPOSITE   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.799
# Date:                Mon, 17 May 2021   Prob (F-statistic):             0.0974
# Time:                        18:16:55   Log-Likelihood:                -2643.0
# No. Observations:                 500   AIC:                             5300.
# Df Residuals:                     493   BIC:                             5329.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9091      2.161      0.883      0.377      -2.337       6.155
# ...

# %%
Train['PredictedY'] = lm.predict(Train)
Test['PredictedY'] = lm.predict(Test)

# %%
plt.scatter(Train['COMPOSITE'], Train['PredictedY'])

# %% [markdown]
# # Model evaluation - Statistical standard

# %%
# RMSE - Root Mean Squared Error, Adjusted R^2
def adjustedMetric(data, model, model_k, yname):
    data['yhat'] = model.predict(data)
    SST = ((data[yname] - data[yname].mean())**2).sum()
    SSR = ((data['yhat'] - data[yname].mean())**2).sum()
    SSE = ((data[yname] - data['yhat'])**2).sum()
    r2 = SSR/SST
    adjustR2 = 1 - (1-r2)*(data.shape[0] - 1)/(data.shape[0] -model_k -1)
    RMSE = (SSE/(data.shape[0] -model_k -1))**0.5
    return adjustR2, RMSE

# %%
def assessTable(test, train, model, model_k, yname):
    r2test, RMSEtest = adjustedMetric(test, model, model_k, yname)
    r2train, RMSEtrain = adjustedMetric(train, model, model_k, yname)
    assessment = pd.DataFrame(index=['R2', 'RMSE'], columns=['Train', 'Test'])
    assessment['Train'] = [r2train, RMSEtrain]
    assessment['Test'] = [r2test, RMSEtest]
    return assessment

# %%
# Get the assement table fo our model
assessTable(Test, Train, lm, 6, 'COMPOSITE')
# Out:
#           Train       Test
# R2     0.009515   0.249029
# RMSE  48.135505  77.561786
